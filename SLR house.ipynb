# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import math
import statsmodels.formula.api as smf

# %%
house_data = pd.read_csv('house.csv')

# %%
house_data.shape
# Out:
# (1459, 2)

# %%
house_data.head()
# Out:
#    GrLivArea  SalePrice
# 0       1262     181500
# 1       1786     223500
# 2       1717     140000
# 3       2198     250000
# 4       1362     143000

# %%
house_data.columns
# Out:
# Index(['GrLivArea', 'SalePrice'], dtype='object')

# %%
house_data.GrLivArea.hist()

# %%
house_data.SalePrice.hist()

# %%
ax = sns.kdeplot(house_data.GrLivArea)

# %%
ax = sns.kdeplot(house_data.SalePrice)

# %%
plt.scatter(house_data.GrLivArea, house_data.SalePrice, alpha=0.5)

# %%
sns.regplot(house_data.GrLivArea, house_data.SalePrice)
# Out:
# C:\Users\PERSONAL\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
house_data.drop(house_data[(house_data.SalePrice <= 200000)
                           & (house_data.GrLivArea >= 4500)].index,inplace=True)

# %%
house_data.iloc[house_data[(house_data.SalePrice <= 200000) & (house_data.GrLivArea >= 4500)].index]
# Out:
# Empty DataFrame
# Columns: [GrLivArea, SalePrice]
# Index: []

# %%
sns.regplot(house_data.GrLivArea, house_data.SalePrice)
# Out:
# C:\Users\PERSONAL\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.linear_model import LinearRegression
x=house_data.iloc[:,0:1]
y=house_data.iloc[:,1]

# %%
x.head(5)
# Out:
#    GrLivArea
# 0       1262
# 1       1786
# 2       1717
# 3       2198
# 4       1362

# %%
y.head(5)
# Out:
# 0    181500
# 1    223500
# 2    140000
# 3    250000
# 4    143000
# Name: SalePrice, dtype: int64

# %%
model2 = LinearRegression()

# %%
model2 = LinearRegression().fit(x, y)

# %%
r_sq = model2.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.5401425348132028

# %%
print('intercept:', model2.intercept_)
# Out:
# intercept: 7169.505757990002

# %%
print('slope:', model2.coef_)
# Out:
# slope: [115.03753205]

# %%
y_prd = model2.intercept_ + (model2.coef_)*1715
print(y_prd)
# Out:
# [204458.87322024]

# %%
model2 = LinearRegression().fit(x, y)
y_pred2 = model2.predict(x)
print(y_pred2)
# Out:
# [152346.87120252 212626.53799565 204688.94828434 ... 276357.33075022
#  131179.96530569 151656.64601023]

# %%
import pandas as pd
uk = pd.read_csv('houseuk.csv')
print(uk)
# Out:
#    GrLivArea
# 0       1715

# %%
y_pred3 = model2.predict(uk)
print(y_pred3)
# Out:
# [204458.87322024]
